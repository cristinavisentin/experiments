# %% [markdown]
# #### Indexes
#
# 1) avgLastBoolScore
# Average reward on last `n` cases
#
# 2) increase (avgScoreDelta)
# Average reward difference between firsts time seeing a case and last ones.
#
# 3) consistency (avgScoreVariation)
# Standard defiation on last cases
