# %% [markdown]
# `seeds` = [1:1:10]
#
# `nOfEvals` = 20000
#
# fitness is avg bool score on last 40 cases
#
# all other score with the unlimited type

# %% [markdown]
# ---
#
# `initialWeightRange` = m.range(min = -0.0; max = 0.0)

# %% [markdown]
# 1) `innerLayers` = [2]
#
# | avgLastBoolScore | increase | consistency |
# |---|---|---|
# | ![](../results/xor/final/xor-problem.txt/2026-01-22--10-56-38/avgLastBoolScore.svg) | ![](../results/xor/final/xor-problem.txt/2026-01-22--10-56-38/increase.svg) | ![](../results/xor/final/xor-problem.txt/2026-01-22--10-56-38/consistency.svg) |
#
# | avgUnlimitedScoreLongerLife | frozenScore |
# |---|---|
# | ![](../results/xor/final/xor-problem.txt/2026-01-22--10-56-38/avgOnAnotherLife.svg) | ![](../results/xor/final/xor-problem.txt/2026-01-22--10-56-38/frozenScore.svg) |

# %% [markdown]
# 2) `innerLayers` = [2; 2]
#
# | avgLastBoolScore | increase | consistency |
# |---|---|---|
# | ![](../results/xor/final/xor-problem.txt/2026-01-22--11-25-43/avgLastBoolScore.svg) | ![](../results/xor/final/xor-problem.txt/2026-01-22--11-25-43/increase.svg) | ![](../results/xor/final/xor-problem.txt/2026-01-22--11-25-43/consistency.svg) |
#
# | avgUnlimitedScoreLongerLife | frozenScore |
# |---|---|
# | ![](../results/xor/final/xor-problem.txt/2026-01-22--11-25-43/avgOnAnotherLife.svg) | ![](../results/xor/final/xor-problem.txt/2026-01-22--11-25-43/frozenScore.svg) |

# %% [markdown]
# 3) `innerLayers` = [8]
#
# | avgLastBoolScore | increase | consistency |
# |---|---|---|
# | ![](../results/xor/final/xor-problem.txt/2026-01-22--12-03-42/avgLastBoolScore.svg) | ![](../results/xor/final/xor-problem.txt/2026-01-22--12-03-42/increase.svg) | ![](../results/xor/final/xor-problem.txt/2026-01-22--12-03-42/consistency.svg) |
#
# | avgUnlimitedScoreLongerLife | frozenScore |
# |---|---|
# | ![](../results/xor/final/xor-problem.txt/2026-01-22--12-03-42/avgOnAnotherLife.svg) | ![](../results/xor/final/xor-problem.txt/2026-01-22--12-03-42/frozenScore.svg) |

# %% [markdown]
# ---
#
# `initialWeightRange` = m.range(min = -0.01; max = 0.01)

# %% [markdown]
# 4) `innerLayers` = [2]
#
# | avgLastBoolScore | increase | consistency |
# |---|---|---|
# | ![](../results/xor/final/xor-problem.txt/2026-01-22--12-38-19/avgLastBoolScore.svg) | ![](../results/xor/final/xor-problem.txt/2026-01-22--12-38-19/increase.svg) | ![](../results/xor/final/xor-problem.txt/2026-01-22--12-38-19/consistency.svg) |
#
# | avgUnlimitedScoreLongerLife | frozenScore |
# |---|---|
# | ![](../results/xor/final/xor-problem.txt/2026-01-22--12-38-19/avgOnAnotherLife.svg) | ![](../results/xor/final/xor-problem.txt/2026-01-22--12-38-19/frozenScore.svg) |

# %% [markdown]
# 5) `innerLayers` = [2; 2]
#
# | avgLastBoolScore | increase | consistency |
# |---|---|---|
# | ![](../results/xor/final/xor-problem.txt/2026-01-22--12-49-53/avgLastBoolScore.svg) | ![](../results/xor/final/xor-problem.txt/2026-01-22--12-49-53/increase.svg) | ![](../results/xor/final/xor-problem.txt/2026-01-22--12-49-53/consistency.svg) |
#
# | avgUnlimitedScoreLongerLife | frozenScore |
# |---|---|
# | ![](../results/xor/final/xor-problem.txt/2026-01-22--12-49-53/avgOnAnotherLife.svg) | ![](../results/xor/final/xor-problem.txt/2026-01-22--12-49-53/frozenScore.svg) |

# %% [markdown]
# 6) `innerLayers` = [8]
#
# | avgLastBoolScore | increase | consistency |
# |---|---|---|
# | ![](../results/xor/final/xor-problem.txt/2026-01-22--12-45-01/avgLastBoolScore.svg) | ![](../results/xor/final/xor-problem.txt/2026-01-22--12-45-01/increase.svg) | ![](../results/xor/final/xor-problem.txt/2026-01-22--12-45-01/consistency.svg) |
#
# | avgUnlimitedScoreLongerLife | frozenScore |
# |---|---|
# | ![](../results/xor/final/xor-problem.txt/2026-01-22--12-45-01/avgOnAnotherLife.svg) | ![](../results/xor/final/xor-problem.txt/2026-01-22--12-45-01/frozenScore.svg) |

# %% [markdown]
# 6) `innerLayers` = [8]
#
# | avgLastBoolScore | increase | consistency |
# |---|---|---|
# | ![](../results/xor/final/xor-problem.txt) | ![](../results/xor/final/xor-problem.txt) | ![](../results/xor/final) |
#
# | avgUnlimitedScoreLongerLife | frozenScore |
# |---|---|
# | ![](../results/xor/final/xor-problem.txt) | ![](../results/xor/final/xor-problem.txt) |
