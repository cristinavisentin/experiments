# %% [markdown]
# `seeds` = [1:1:30]
#
# `nOfEvals` = 30000
#
# `initialWeightRange` = m.range(min = -0.01; max = 0.01)

# %% [markdown]
# 1) `innerLayers` = [2]
#
# | | | |
# |---|---|---|
# | ![](../results/xor/terminator/2026-01-19--14-57-02/avgLastBoolScore.svg) | ![](../results/xor/terminator/2026-01-19--14-57-02/increase.svg) | ![](../results/xor/terminator/2026-01-19--14-57-02/consistency.svg) |

# %% [markdown]
# 2) `innerLayers` = [2; 2]
#
# | | | |
# |---|---|---|
# | ![](../results/xor/terminator/2026-01-19--15-21-44/avgLastBoolScore.svg) | ![](../results/xor/terminator/2026-01-19--14-57-02/increase.svg) | ![](../results/xor/terminator/2026-01-19--14-57-02/consistency.svg) |

# %% [markdown]
# 3) `innerLayers` = [8]
#
# | | | |
# |---|---|---|
# | ![](../results/xor/grande/2026-01-19--17-25-08/avgLastBoolScore.svg) | ![](../results/xor/grande/2026-01-19--17-25-08/increase.svg) | ![](../results/xor/grande/2026-01-19--17-25-08/consistency.svg) |
